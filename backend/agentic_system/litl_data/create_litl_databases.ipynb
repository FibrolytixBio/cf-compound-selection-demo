# %%
import pickle

from dotenv import load_dotenv
import dspy

load_dotenv("../../.env")
lm = dspy.LM("gemini/gemini-2.5-pro", temperature=0.9, cache=False)
dspy.settings.configure(lm=lm, track_usage=True)

# %%
# Load the object from the pickle file
with open(
    "eval_summarized_tool_results.pkl",
    "rb",
) as f:
    eval_summarized_tool_results = pickle.load(f)

# Display the loaded object
len(eval_summarized_tool_results)
# Out:
# 125

# %%
class SummarizeRun(dspy.Signature):
    """Produce a concise MARKDOWN of the run. Summarize information where possible to make it more concise, but never lose information.

    FORMAT:
    ## Compound
    <compound_name>

    ## Trajectory
    - Step 0:
        - <reasoning>
        - <tool>
        - <observation>
    - Step 1: ...

    ## Reasoning
    <reasoning text>

    ## Predicted Efficacy
    <predicted_efficacy>

    ## Confidence
    <confidence>
    """

    compound_name: str = dspy.InputField(
        desc="The name of the compound being evaluated"
    )
    trajectory: str = dspy.InputField(desc="The raw trace data to summarize")
    reasoning: str = dspy.InputField(
        desc="The reasoning used to arrive at the trace conclusion."
    )
    predicted_efficacy: float = dspy.InputField(
        desc="The predicted efficacy of the compound."
    )
    confidence: float = dspy.InputField(desc="The confidence level prediction.")
    summary: str = dspy.OutputField(
        desc="A concise, structured summary of key information formatted for use by ReAct agent LLM"
    )


summarizer_lm = dspy.LM(
    "gemini/gemini-2.5-flash-lite", temperature=0.0, cache=True, max_tokens=25000
)


class ReflectRun(dspy.Signature):
    """Calculate the error of the run as the absolute difference between the predicted efficacy and the real efficacy.
    Then, produce a thorough reflection as to why the error occurred and how to improve the prediction accuracy in future runs.

    FORMAT:
    ## Real Efficacy
    <real efficacy>

    ## Error
    <|predicted efficacy - real efficacy|>

    ## Error Reasoning
    <error reasoning text>

    ## Improvements
        1) <improvement 1>
        2) <improvement 2>
        3) ...
    """

    summarized_run: str = dspy.InputField(desc="The the run being evaluated")
    real_efficacy: float = dspy.InputField(desc="The actual efficacy of the compound.")
    reflection: str = dspy.OutputField()


reflection_lm = dspy.LM(
    "gemini/gemini-2.5-pro", temperature=0.5, cache=True, max_tokens=25000
)

result_num = 0
docs = []
for result in eval_summarized_tool_results:
    compound_name = result[0]["compound_name"]
    efficacy = round(result[0]["cf_efficacy"], 2)
    run = result[1]

    print("Processing result", result_num, "for compound", compound_name)

    with dspy.context(lm=summarizer_lm):
        summary_predict = dspy.Predict(SummarizeRun)
        summary_result = summary_predict(
            compound_name=compound_name,
            trajectory=run.trajectory,
            reasoning=run.reasoning,
            predicted_efficacy=run.predicted_efficacy,
            confidence=run.confidence,
        )

    with dspy.context(lm=reflection_lm):
        reflection_predict = dspy.Predict(ReflectRun)
        reflection_result = reflection_predict(
            summarized_run=summary_result.summary,
            real_efficacy=efficacy,
        )

    doc = f"""# Agent Run Summary
{summary_result.summary}

# Accuracy Reflection
{reflection_result.reflection}"""

    docs.append(doc)
    print("Finished result", result_num)

    result_num += 1

len(docs)
# Out:
# Processing result 0 for compound Luminespib
# Finished result 0
# Processing result 1 for compound Tanespimycin
# Finished result 1
# Processing result 2 for compound MK-2866
# Finished result 2
# Processing result 3 for compound Navitoclax
# Finished result 3
# Processing result 4 for compound Finasteride
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='[[ ## re...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Finished result 4
# Processing result 5 for compound Veliparib
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='[[ ## su...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Finished result 5
# Processing result 6 for compound GSK1904529A
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content="[[ ## su...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Finished result 6
# Processing result 7 for compound KU-55933
# Finished result 7
# Processing result 8 for compound PHA-665752
# Finished result 7
# Processing result 8 for compound PHA-665752
# Finished result 8
# Processing result 9 for compound Nilotinib
# Finished result 8
# Processing result 9 for compound Nilotinib
# Finished result 9
# Processing result 10 for compound STF-62247
# Finished result 9
# Processing result 10 for compound STF-62247
# Finished result 10
# Processing result 11 for compound Etodolac
# Finished result 10
# Processing result 11 for compound Etodolac
# Finished result 11
# Processing result 12 for compound PD0325901
# Finished result 11
# Processing result 12 for compound PD0325901
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content="[[ ## re...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Finished result 12
# Processing result 13 for compound BIBR 1532
# Finished result 13
# Processing result 14 for compound Vemurafenib
# Finished result 13
# Processing result 14 for compound Vemurafenib
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='## Compo...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "su...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content='{\n  "su...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Finished result 14
# Processing result 15 for compound Varespladib
# Finished result 15
# Processing result 16 for compound Temsirolimus
# Finished result 15
# Processing result 16 for compound Temsirolimus
# Finished result 16
# Processing result 17 for compound Ridaforolimus
# Finished result 16
# Processing result 17 for compound Ridaforolimus
# Finished result 17
# Processing result 18 for compound SU11274
# Finished result 17
# Processing result 18 for compound SU11274
# Finished result 18
# Processing result 19 for compound Dutasteride
# Finished result 18
# Processing result 19 for compound Dutasteride
# Finished result 19
# Processing result 20 for compound Fluvoxamine maleate
# Finished result 19
# Processing result 20 for compound Fluvoxamine maleate
# Finished result 20
# Processing result 21 for compound PF-04217903
# Finished result 20
# Processing result 21 for compound PF-04217903
# Finished result 21
# Processing result 22 for compound Etomidate
# Finished result 21
# Processing result 22 for compound Etomidate
# Finished result 22
# Processing result 23 for compound PD184352
# Finished result 22
# Processing result 23 for compound PD184352
# Finished result 23
# Processing result 24 for compound Everolimus
# Finished result 23
# Processing result 24 for compound Everolimus
# Finished result 24
# Processing result 25 for compound Luminespib
# Finished result 24
# Processing result 25 for compound Luminespib
# Finished result 25
# Processing result 26 for compound Tanespimycin
# Finished result 25
# Processing result 26 for compound Tanespimycin
# Finished result 26
# Processing result 27 for compound MK-2866
# Finished result 26
# Processing result 27 for compound MK-2866
# Finished result 27
# Processing result 28 for compound Navitoclax
# Finished result 27
# Processing result 28 for compound Navitoclax
# Finished result 28
# Processing result 29 for compound Finasteride
# Finished result 28
# Processing result 29 for compound Finasteride
# Finished result 29
# Processing result 30 for compound Veliparib
# Finished result 29
# Processing result 30 for compound Veliparib
# Finished result 30
# Processing result 31 for compound GSK1904529A
# Finished result 30
# Processing result 31 for compound GSK1904529A
# Finished result 31
# Processing result 32 for compound KU-55933
# Finished result 31
# Processing result 32 for compound KU-55933
# Finished result 32
# Processing result 33 for compound PHA-665752
# Finished result 32
# Processing result 33 for compound PHA-665752
# Finished result 33
# Processing result 34 for compound Nilotinib
# Finished result 33
# Processing result 34 for compound Nilotinib
# Finished result 34
# Processing result 35 for compound STF-62247
# Finished result 34
# Processing result 35 for compound STF-62247
# Finished result 35
# Processing result 36 for compound Etodolac
# Finished result 35
# Processing result 36 for compound Etodolac
# Finished result 36
# Processing result 37 for compound PD0325901
# Finished result 36
# Processing result 37 for compound PD0325901
# Finished result 37
# Processing result 38 for compound BIBR 1532
# Finished result 37
# Processing result 38 for compound BIBR 1532
# Finished result 38
# Processing result 39 for compound Vemurafenib
# Finished result 38
# Processing result 39 for compound Vemurafenib
# Finished result 39
# Processing result 40 for compound Varespladib
# Finished result 39
# Processing result 40 for compound Varespladib
# Finished result 40
# Processing result 41 for compound Temsirolimus
# Finished result 40
# Processing result 41 for compound Temsirolimus
# Finished result 41
# Processing result 42 for compound Ridaforolimus
# Finished result 41
# Processing result 42 for compound Ridaforolimus
# Finished result 42
# Processing result 43 for compound SU11274
# Finished result 42
# Processing result 43 for compound SU11274
# Finished result 43
# Processing result 44 for compound Dutasteride
# Finished result 43
# Processing result 44 for compound Dutasteride
# /Users/roshankern/Desktop/Github/cf-compound-selection-demo/backend/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 9 fields but got 5: Expected `Message` - serialized value may not be as expected [input_value=Message(content="## Compo...er_specific_fields=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [input_value=Choices(finish_reason='st...r_specific_fields=None)), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(
# Finished result 44
# Processing result 45 for compound Fluvoxamine maleate
# Finished result 45
# Processing result 46 for compound PF-04217903
# Finished result 45
# Processing result 46 for compound PF-04217903
# Finished result 46
# Processing result 47 for compound Etomidate
# Finished result 46
# Processing result 47 for compound Etomidate
# Finished result 47
# Processing result 48 for compound PD184352
# Finished result 47
# Processing result 48 for compound PD184352
# Finished result 48
# Processing result 49 for compound Everolimus
# Finished result 48
# Processing result 49 for compound Everolimus
# Finished result 49
# Processing result 50 for compound Luminespib
# Finished result 49
# Processing result 50 for compound Luminespib
# Finished result 50
# Processing result 51 for compound Tanespimycin
# Finished result 50
# Processing result 51 for compound Tanespimycin
# Finished result 51
# Processing result 52 for compound MK-2866
# Finished result 51
# Processing result 52 for compound MK-2866
# Finished result 52
# Processing result 53 for compound Navitoclax
# Finished result 52
# Processing result 53 for compound Navitoclax
# Finished result 53
# Processing result 54 for compound Finasteride
# Finished result 53
# Processing result 54 for compound Finasteride
# Finished result 54
# Processing result 55 for compound Veliparib
# Finished result 54
# Processing result 55 for compound Veliparib
# Finished result 55
# Processing result 56 for compound GSK1904529A
# Finished result 55
# Processing result 56 for compound GSK1904529A
# Finished result 56
# Processing result 57 for compound KU-55933
# Finished result 56
# Processing result 57 for compound KU-55933
# Finished result 57
# Processing result 58 for compound PHA-665752
# Finished result 57
# Processing result 58 for compound PHA-665752
# Finished result 58
# Processing result 59 for compound Nilotinib
# Finished result 58
# Processing result 59 for compound Nilotinib
# Finished result 59
# Processing result 60 for compound STF-62247
# Finished result 59
# Processing result 60 for compound STF-62247
# Finished result 60
# Processing result 61 for compound Etodolac
# Finished result 60
# Processing result 61 for compound Etodolac
# Finished result 61
# Processing result 62 for compound PD0325901
# Finished result 61
# Processing result 62 for compound PD0325901
# Finished result 62
# Processing result 63 for compound BIBR 1532
# Finished result 62
# Processing result 63 for compound BIBR 1532
# Finished result 63
# Processing result 64 for compound Vemurafenib
# Finished result 63
# Processing result 64 for compound Vemurafenib
# Finished result 64
# Processing result 65 for compound Varespladib
# Finished result 64
# Processing result 65 for compound Varespladib
# Finished result 65
# Processing result 66 for compound Temsirolimus
# Finished result 65
# Processing result 66 for compound Temsirolimus
# Finished result 66
# Processing result 67 for compound Ridaforolimus
# Finished result 66
# Processing result 67 for compound Ridaforolimus
# Finished result 67
# Processing result 68 for compound SU11274
# Finished result 67
# Processing result 68 for compound SU11274
# Finished result 68
# Processing result 69 for compound Dutasteride
# Finished result 68
# Processing result 69 for compound Dutasteride
# Finished result 69
# Processing result 70 for compound Fluvoxamine maleate
# Finished result 69
# Processing result 70 for compound Fluvoxamine maleate
# Finished result 70
# Processing result 71 for compound PF-04217903
# Finished result 70
# Processing result 71 for compound PF-04217903
# Finished result 71
# Processing result 72 for compound Etomidate
# Finished result 71
# Processing result 72 for compound Etomidate
# Finished result 72
# Processing result 73 for compound PD184352
# Finished result 72
# Processing result 73 for compound PD184352
# Finished result 73
# Processing result 74 for compound Everolimus
# Finished result 73
# Processing result 74 for compound Everolimus
# Finished result 74
# Processing result 75 for compound Luminespib
# Finished result 74
# Processing result 75 for compound Luminespib
# Finished result 75
# Processing result 76 for compound Tanespimycin
# Finished result 75
# Processing result 76 for compound Tanespimycin
# Finished result 76
# Processing result 77 for compound MK-2866
# Finished result 76
# Processing result 77 for compound MK-2866
# Finished result 77
# Processing result 78 for compound Navitoclax
# Finished result 77
# Processing result 78 for compound Navitoclax
# Finished result 78
# Processing result 79 for compound Finasteride
# Finished result 78
# Processing result 79 for compound Finasteride
# Finished result 79
# Processing result 80 for compound Veliparib
# Finished result 79
# Processing result 80 for compound Veliparib
# Finished result 80
# Processing result 81 for compound GSK1904529A
# Finished result 80
# Processing result 81 for compound GSK1904529A
# Finished result 81
# Processing result 82 for compound KU-55933
# Finished result 81
# Processing result 82 for compound KU-55933
# Finished result 82
# Processing result 83 for compound PHA-665752
# Finished result 82
# Processing result 83 for compound PHA-665752
# Finished result 83
# Processing result 84 for compound Nilotinib
# Finished result 83
# Processing result 84 for compound Nilotinib
# Finished result 84
# Processing result 85 for compound STF-62247
# Finished result 84
# Processing result 85 for compound STF-62247
# Finished result 85
# Processing result 86 for compound Etodolac
# Finished result 85
# Processing result 86 for compound Etodolac
# Finished result 86
# Processing result 87 for compound PD0325901
# Finished result 86
# Processing result 87 for compound PD0325901
# Finished result 87
# Processing result 88 for compound BIBR 1532
# Finished result 87
# Processing result 88 for compound BIBR 1532
# Finished result 88
# Processing result 89 for compound Vemurafenib
# Finished result 88
# Processing result 89 for compound Vemurafenib
# Finished result 89
# Processing result 90 for compound Varespladib
# Finished result 89
# Processing result 90 for compound Varespladib
# Finished result 90
# Processing result 91 for compound Temsirolimus
# Finished result 90
# Processing result 91 for compound Temsirolimus
# Finished result 91
# Processing result 92 for compound Ridaforolimus
# Finished result 91
# Processing result 92 for compound Ridaforolimus
# Finished result 92
# Processing result 93 for compound SU11274
# Finished result 92
# Processing result 93 for compound SU11274
# Finished result 93
# Processing result 94 for compound Dutasteride
# Finished result 93
# Processing result 94 for compound Dutasteride
# Finished result 94
# Processing result 95 for compound Fluvoxamine maleate
# Finished result 94
# Processing result 95 for compound Fluvoxamine maleate
# Finished result 95
# Processing result 96 for compound PF-04217903
# Finished result 95
# Processing result 96 for compound PF-04217903
# Finished result 96
# Processing result 97 for compound Etomidate
# Finished result 96
# Processing result 97 for compound Etomidate
# Finished result 97
# Processing result 98 for compound PD184352
# Finished result 97
# Processing result 98 for compound PD184352
# Finished result 98
# Processing result 99 for compound Everolimus
# Finished result 98
# Processing result 99 for compound Everolimus
# Finished result 99
# Processing result 100 for compound Luminespib
# Finished result 99
# Processing result 100 for compound Luminespib
# Finished result 100
# Processing result 101 for compound Tanespimycin
# Finished result 100
# Processing result 101 for compound Tanespimycin
# Finished result 101
# Processing result 102 for compound MK-2866
# Finished result 101
# Processing result 102 for compound MK-2866
# Finished result 102
# Processing result 103 for compound Navitoclax
# Finished result 102
# Processing result 103 for compound Navitoclax
# Finished result 103
# Processing result 104 for compound Finasteride
# Finished result 103
# Processing result 104 for compound Finasteride
# Finished result 104
# Processing result 105 for compound Veliparib
# Finished result 104
# Processing result 105 for compound Veliparib
# Finished result 105
# Processing result 106 for compound GSK1904529A
# Finished result 105
# Processing result 106 for compound GSK1904529A
# Finished result 106
# Processing result 107 for compound KU-55933
# Finished result 106
# Processing result 107 for compound KU-55933
# Finished result 107
# Processing result 108 for compound PHA-665752
# Finished result 107
# Processing result 108 for compound PHA-665752
# Finished result 108
# Processing result 109 for compound Nilotinib
# Finished result 108
# Processing result 109 for compound Nilotinib
# Finished result 109
# Processing result 110 for compound STF-62247
# Finished result 109
# Processing result 110 for compound STF-62247
# Finished result 110
# Processing result 111 for compound Etodolac
# Finished result 110
# Processing result 111 for compound Etodolac
# Finished result 111
# Processing result 112 for compound PD0325901
# Finished result 111
# Processing result 112 for compound PD0325901
# Finished result 112
# Processing result 113 for compound BIBR 1532
# Finished result 112
# Processing result 113 for compound BIBR 1532
# Finished result 113
# Processing result 114 for compound Vemurafenib
# Finished result 113
# Processing result 114 for compound Vemurafenib
# Finished result 114
# Processing result 115 for compound Varespladib
# Finished result 114
# Processing result 115 for compound Varespladib
# Finished result 115
# Processing result 116 for compound Temsirolimus
# Finished result 115
# Processing result 116 for compound Temsirolimus
# Finished result 116
# Processing result 117 for compound Ridaforolimus
# Finished result 116
# Processing result 117 for compound Ridaforolimus
# Finished result 117
# Processing result 118 for compound SU11274
# Finished result 117
# Processing result 118 for compound SU11274
# Finished result 118
# Processing result 119 for compound Dutasteride
# Finished result 118
# Processing result 119 for compound Dutasteride
# Finished result 119
# Processing result 120 for compound Fluvoxamine maleate
# Finished result 119
# Processing result 120 for compound Fluvoxamine maleate
# Finished result 120
# Processing result 121 for compound PF-04217903
# Finished result 120
# Processing result 121 for compound PF-04217903
# Finished result 121
# Processing result 122 for compound Etomidate
# Finished result 121
# Processing result 122 for compound Etomidate
# Finished result 122
# Processing result 123 for compound PD184352
# Finished result 122
# Processing result 123 for compound PD184352
# Finished result 123
# Processing result 124 for compound Everolimus
# Finished result 123
# Processing result 124 for compound Everolimus
# Finished result 124
# Finished result 124
# 125

# %%
# Save the docs list to a pickle file
with open(
    "summarized_tool_run_docs.pkl",
    "wb",
) as f:
    pickle.dump(docs, f)

print("Docs saved to summarized_tool_run_docs.pkl")
# Out:
# Docs saved to summarized_tool_run_docs.pkl

# %%
embedder = dspy.Embedder("openai/text-embedding-3-small", dimensions=512)
search = dspy.retrievers.Embeddings(
    embedder=embedder, corpus=docs, k=1
)  # FAISS auto-handled if installed


# 2) tiny RAG over memory
class MemoryRAG(dspy.Module):
    def __init__(self):
        self.respond = dspy.Predict("context, query -> answer: str")

    def forward(self, query):
        ctx = search(query).passages
        numbered_ctx = [f"Context {i + 1}:\n{passage}" for i, passage in enumerate(ctx)]
        return self.respond(context="\n\n".join(numbered_ctx), query=query)


rag = MemoryRAG()

# 3) example query: retrieve prior runs to estimate efficacy
q = "HSP90 inhibitor efficacy"
print(rag(query=q).answer)

# %%
dspy.inspect_history()
